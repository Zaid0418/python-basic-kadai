# %%
def product_price(item_price, tax):
    price_including_tax = item_price * tax /100 + item_price
    return price_including_tax
    price_including_tax(110, 10) 
    print(f"{price_including_tax}"円)
