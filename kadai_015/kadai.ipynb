# %%
# クラスを定義する
class Human:
    def __init__(self):
        # 属性を定義する
        self.name = ""
        self.age = ""


name = Human()
age = Human()


#　属性にアクセスし,値を代入する
name = "名前" 
age = "年齢"

# 属性にアクセスし、値を出力する
print(name)
print(age)
